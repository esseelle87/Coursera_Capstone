# %% [markdown]
# # Geneva House Renting Consultancy
# Capstone Project, Applied Data Science Capstone by IBM/Coursera, Simone Lisi.
#
# In this notebook, we will collect the top venues within a 500m radius with respct to each prperty we prevously scraped from the immoscout24.ch listing website.
#
# We will then categorize each venue according to the macro-categories: 'Food', 'Shop & Service', 'Travel & Transport', 'Outdoors & Recreation', 'Arts & Entertainment', 'Nightlife Spot', 'Professional & Other Places', 'Residence'.
#
# We will add a feature in our properties database counting the number of nearby venues in each of these macro-categories.
#
#
# The reults will be stored in the "geneva_allapp.csv", that will be later used for classification.
#
# Some cells are enclosed markdown cells, starting and ending with: ////////////////////
# //////////////////// ////////////////////
#
# These cells are set as markdown, as they are not supposed to be run except when we want to scrape new data, or install missing packages. For this they can be set to 'code'. Otherwise, the program will load data previousely scraped and stored.

# %% [markdown]
# ## Installing packages. Set this cell to 'code' if needed.
# !conda install -c anaconda lxml --yes
#
# !conda install -c conda-forge geopy --yes
#
# !conda install -c conda-forge folium=0.5.0 --yes

# %%
### importing libraries
import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import json # library to handle JSON files
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe
import folium # map rendering library
import geopy.distance
import seaborn as sns
import matplotlib.pyplot as plt
import pylab as pl
import numpy as np
# %matplotlib inline

# %%
### Geneva coordinates
address = 'Geneva, switzerland'

geolocator = Nominatim(user_agent= "To_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Geneva are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Geneva are 46.2017559, 6.1466014.

# %%
#hidden foursquare credentials
CLIENT_ID = 'xxxx'#  Foursquare ID
CLIENT_SECRET = 'xxxx' #  Foursquare Secret

VERSION = '20180605' # Foursquare API version
LIMIT  = 100

# %%
### define function to colect venues around a location

def getVenues(lat, lng, radius=500):
    
    venues_list=[]
  
    # create the API request URL
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
        CLIENT_ID, 
        CLIENT_SECRET, 
        VERSION, 
        lat, 
        lng, 
        radius, 
        LIMIT)
            
    # make the GET request
    try: 
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name'],
            v['venue']['categories'][0]['id']) for v in results])
    
    except:
         # return only relevant information for each nearby venue
        venues_list.append([(
            lat, 
            lng, 
            'missing', 
            'missing', 
            'missing', 
            'missing', 
            'missing' )])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = [ 'Neighborhood Latitude', 
                'Neighborhood Longitude', 
                'Venue', 
                'Venue Latitude', 
                'Venue Longitude', 
                'Venue Category',
                'categoryId']
    
    
        
    return(nearby_venues)

# %%
#Loadind dataframe as saved in ScrapingImmoscout24ch_FA.ipynb
df = pd.read_json (r'db_geneva_app_FA.json')
df.head()
# Out:
#           cityName  extraPrice  price  latitude  longitude  numberOfRooms  \
# 6065071     Genève       350.0   2550  46.19363    6.16698            4.0
# 6046525     Genève       200.0   4200  46.19646    6.16090            5.5
# 6063101     Genève       170.0   2810  46.20429    6.15891            4.0
# 6054808     Genève       250.0   4750  46.19523    6.15391            7.0
# 6037279  Le Lignon       200.0   2700  46.20313    6.09613            6.0
#
#                         street  surfaceLiving   zip  pricePerRoom  \
# 6065071    Rue Le Corbusier 18             85  1208    637.500000
# 6046525  Route de Malagnou 40E            110  1208    763.636364
# 6063101  Rue du 31-Décembre 16             60  1207    702.500000
# 6054808           Rue Marignac            165  1206    678.571429
# 6037279       Avenue du Lignon            107  1219    450.000000
#
#          pricePerSqm  price_dev
# 6065071    30.000000  -0.171515
# 6046525    38.181818   0.105094
# 6063101    46.833333   0.211344
# 6054808    28.787879  -0.148491
# 6037279    25.233645  -0.357799

# %%
adress_CTS = 'gare cornavin, Geneva'
location = geolocator.geocode(adress_CTS)
latitude_CTS = location.latitude
longitude_CTS = location.longitude
print('The geograpical coordinate of Cornavin Train Station are {}, {}.'.format(latitude_CTS, longitude_CTS))
# Out:
# The geograpical coordinate of Cornavin Train Station are 46.2098507, 6.141525.

# %%
### create a map
address = 'Geneva, Switzerland'

geolocator = Nominatim(user_agent="To_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Geneva are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Geneva are 46.2017559, 6.1466014.

# %%
map_geneva = folium.Map(location=[latitude, longitude], zoom_start=12)

# add markers to map
for lat, lng, price, n_rooms, area in zip(df['latitude'], df['longitude'], df['price'], df['numberOfRooms'], df['surfaceLiving']):
    label = '{:.0f}, {:.0f}, {:.0f}'.format(price, n_rooms, area)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_geneva)  

    
map_geneva
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## //////////////////// //////////////////// ////////////////////
# ## The following cells are meant to query foursquare. They should be run only once (by converting them into 'code'). Then the data are stored in a dictionary for later use. When using this code from the second time on, skip from here...

# %% [markdown]
# venues_per_app_dic = {}
#
# for app_id, lat, lng in zip(df.index, df['latitude'], df['longitude']):
#
#     venues_per_app_dic[app_id] = getVenues(lat, lng)

# %% [markdown]
# #len(venues_per_app_dic.keys())
# venues_per_app_dic[6059594]

# %% [markdown]
# ##some calls might have failed. I identify them and then run again the foursquare query for those (in the cell below)
# failed_call_id =[]
# for key in venues_per_app_dic.keys():
#     if venues_per_app_dic[key].iloc[0,3] == 'missing':
#         failed_call_id.append(key)
#
# len(failed_call_id)

# %% [markdown]
# for element in failed_call_id:
#     venues_per_app_dic[element] = getVenues(df.loc[element, 'latitude'], df.loc[element, 'longitude'])

# %% [markdown]
# ## ... to here
# ## //////////////////// //////////////////// ////////////////////

# %%
#### save/import dictionary of dataframes.
### each key of the dictionary corresponds to a property identifier. The associate dataframe contains 
### informations the top venues around each property

import csv
import os
root = 'venues_per_app'
os.path.join(root, 'some_file.csv')

def dic_save(dic):
    for key, val in dic.items():
        val.to_csv(os.path.join(root, 'data_{}.csv'.format(str(key))))
        
    with open(os.path.join(root, 'key.txt'), "w") as f: #saving keys to file
        f.write(str(list(dic.keys())))

def dic_load():
    """Reading data from keys"""
    with open(os.path.join(root, 'key.txt'), "r") as f:
        keys = eval(f.read())

    dic = {}    
    for key in keys:
        dic[key] = pd.read_csv(os.path.join(root, 'data_{}.csv'.format(str(key))))

    return dic
#### uncomment the line below for saving the dictionary. Leave it commented
#### for  importing it
#dic_save(venues_per_app_dic)

dic2 = dic_load()

# %%
## let's check how one of the dataframes looks like
dic2[list(dic2.keys())[3]].head()
# Out:
#    Unnamed: 0  Neighborhood Latitude  Neighborhood Longitude  \
# 0           0               46.19523                 6.15391
# 1           1               46.19523                 6.15391
# 2           2               46.19523                 6.15391
# 3           3               46.19523                 6.15391
# 4           4               46.19523                 6.15391
#
#                    Venue  Venue Latitude  Venue Longitude  \
# 0              Le Sesflo       46.196000         6.155568
# 1      Le Pain Quotidien       46.193110         6.154550
# 2    Gaucho Churrascaria       46.196381         6.152834
# 3  Tea-room de l'Athénée       46.194739         6.154934
# 4           Osteria Zaza       46.192437         6.153315
#
#            Venue Category                categoryId
# 0      Italian Restaurant  4bf58dd8d48988d110941735
# 1                  Bakery  4bf58dd8d48988d16a941735
# 2  Argentinian Restaurant  4bf58dd8d48988d107941735
# 3                Tea Room  4bf58dd8d48988d1dc931735
# 4              Restaurant  4bf58dd8d48988d1c4941735

# %%
# removing additional columns Unnamed:..
for key in dic2.keys():
    if('Unnamed: 0.1' in dic2[key].columns):
        dic2[key].drop(axis=1, labels = 'Unnamed: 0.1', inplace = True)
    if('Unnamed: 0' in dic2[key].columns):
        dic2[key].drop(axis=1, labels = 'Unnamed: 0', inplace = True)

# %%
dic2[list(dic2.keys())[3]].head()
# Out:
#    Neighborhood Latitude  Neighborhood Longitude                  Venue  \
# 0               46.19523                 6.15391              Le Sesflo
# 1               46.19523                 6.15391      Le Pain Quotidien
# 2               46.19523                 6.15391    Gaucho Churrascaria
# 3               46.19523                 6.15391  Tea-room de l'Athénée
# 4               46.19523                 6.15391           Osteria Zaza
#
#    Venue Latitude  Venue Longitude          Venue Category  \
# 0       46.196000         6.155568      Italian Restaurant
# 1       46.193110         6.154550                  Bakery
# 2       46.196381         6.152834  Argentinian Restaurant
# 3       46.194739         6.154934                Tea Room
# 4       46.192437         6.153315              Restaurant
#
#                  categoryId
# 0  4bf58dd8d48988d110941735
# 1  4bf58dd8d48988d16a941735
# 2  4bf58dd8d48988d107941735
# 3  4bf58dd8d48988d1dc931735
# 4  4bf58dd8d48988d1c4941735

# %% [markdown]
# ### We will now add all the categories to which a location belongs to each dictionary.
# The maximum parents category on foursquare is 4, so we will add 4 new columns.

# %%
## loading the dictionary containing, for each subcategory, all the parent categories, as prepared in
## Scraping_foursquare_cat_FA.ipynb
with open('dic_all_cat.json', "r") as f:
        dic_all_cat = eval(f.read())

# %%
for key in dic2.keys():
    venues_ids = list(dic2[key].loc[:, 'categoryId' ])
    lv0_list = []
    for element in venues_ids:
        try:
            lv0_list.append(dic_all_cat[dic_all_cat[element][2+0]][0])
        except:
             lv0_list.append(None)
    dic2[key]['Lv0'] = pd.Series(lv0_list)
    
    lv1_list = []
    for element in venues_ids:
        try:
            lv1_list.append(dic_all_cat[dic_all_cat[element][2+1]][0])
        except:
             lv1_list.append(None)
    dic2[key]['Lv1'] = pd.Series(lv1_list)
    
    
    lv2_list = []
    for element in venues_ids:
        try:
            lv2_list.append(dic_all_cat[dic_all_cat[element][2+2]][0])
        except:
             lv2_list.append(None)
    dic2[key]['Lv2'] = pd.Series(lv2_list)
    
    lv3_list = []
    for element in venues_ids:
        try:
            lv3_list.append(dic_all_cat[dic_all_cat[element][2+3]][0])
        except:
             lv3_list.append(None)
    dic2[key]['Lv3'] = pd.Series(lv3_list)

# %%
# we look at one of the results as an example
dic2[list(dic2.keys())[7]]
# Out:
#     Neighborhood Latitude  Neighborhood Longitude  \
# 0                46.20976                 6.14364
# 1                46.20976                 6.14364
# 2                46.20976                 6.14364
# 3                46.20976                 6.14364
# 4                46.20976                 6.14364
# 5                46.20976                 6.14364
# 6                46.20976                 6.14364
# 7                46.20976                 6.14364
# 8                46.20976                 6.14364
# 9                46.20976                 6.14364
# 10               46.20976                 6.14364
# 11               46.20976                 6.14364
# 12               46.20976                 6.14364
# 13               46.20976                 6.14364
# 14               46.20976                 6.14364
# 15               46.20976                 6.14364
# 16               46.20976                 6.14364
# 17               46.20976                 6.14364
# 96         6.142384                       Diner  4bf58dd8d48988d147941735
#
#                             Lv0                         Lv1  \
# 0                Shop & Service              Chocolate Shop
# 1                          Food          Falafel Restaurant
# 2                          Food            Asian Restaurant
# 3                          Food                 Coffee Shop
# 4                          Food          Spanish Restaurant
# 5         Outdoors & Recreation                       Plaza
# 6                Nightlife Spot                         Bar
# 7                          Food          Spanish Restaurant
# 8            Travel & Transport  Tourist Information Center
# 9                          Food           French Restaurant
# 10                         Food          Seafood Restaurant
# 11               Shop & Service            Department Store
# 12                         Food            Asian Restaurant
# 13               Nightlife Spot                         Bar
# 14                         Food            Asian Restaurant
# 15                         Food                Burger Joint
# 16               Nightlife Spot                         Bar
# 17                         Food                  Restaurant
# 18                         Food           French Restaurant
# 19                         Food                Burger Joint
# 20                         Food           French Restaurant
# 21           Travel & Transport                       Hotel
# 22                         Food                Dessert Shop
# 23               Nightlife Spot                         Bar
# 24           Travel & Transport                       Hotel
# 25                         Food                 Coffee Shop
# 26               Nightlife Spot                         Bar
# 27                         Food            Asian Restaurant
# 28                         Food                        Café
# 29           Travel & Transport                       Hotel
# 30                         Food                Dessert Shop
# 31                         Food                Dessert Shop
# 32               Shop & Service     Health & Beauty Service
# 33        Outdoors & Recreation                       Plaza
# 34                         Food           French Restaurant
# 35           Travel & Transport                       Hotel
# 36           Travel & Transport                       Hotel
# 37        Outdoors & Recreation                       Plaza
# 38               Nightlife Spot                         Bar
# 39                         Food                 Coffee Shop
# 40           Travel & Transport                       Hotel
# 41                         Food           Indian Restaurant
# 42                         Food            Asian Restaurant
# 43               Shop & Service                         Spa
# 44                         Food          Italian Restaurant
# 45                         Food                    Tea Room
# 46                         Food                Burger Joint
# 47               Shop & Service           Food & Drink Shop
# 48               Nightlife Spot                      Lounge
# 49                         Food                Dessert Shop
# 50           Travel & Transport                       Hotel
# 51                         Food                        Café
# 52                         Food           Indian Restaurant
# 53                         Food                Dessert Shop
# 54                         Food          African Restaurant
# 55                         Food    Mediterranean Restaurant
# 56                         Food              Sandwich Place
# 57  Professional & Other Places         Government Building
# 58               Nightlife Spot                         Bar
# 59                         Food                 Pizza Place
# 60                         Food            Asian Restaurant
# 61                         Food              Sandwich Place
# 62        Outdoors & Recreation                        Park
# 63                         Food           French Restaurant
# 64                         Food                  Restaurant
# 65                         Food             Bubble Tea Shop
# 66                         Food            Asian Restaurant
# 67                         Food          Italian Restaurant
# 68           Travel & Transport                       Hotel
# 69               Nightlife Spot                         Bar
# 70                         Food                 Salad Place
# 71           Travel & Transport               Train Station
# 72                         Food                  Restaurant
# 73        Outdoors & Recreation          Athletics & Sports
# 74               Nightlife Spot                         Bar
# 75                         Food   Latin American Restaurant
# 76                         Food            Asian Restaurant
# 77               Nightlife Spot                         Bar
# 78                         Food                 Coffee Shop
# 79           Travel & Transport                       Hotel
# 80         Arts & Entertainment                 Comedy Club
# 81                         Food                      Bakery
# 82                         Food            Asian Restaurant
# 83           Travel & Transport                       Hotel
# 84           Travel & Transport                       Hotel
# 85               Nightlife Spot                         Bar
# 86         Arts & Entertainment               Movie Theater
# 87                         Food           French Restaurant
# 88           Travel & Transport                       Hotel
# 89                         Food                        Café
# 90                         Food                      Bakery
# 91                         Food            Asian Restaurant
# 92                         Food        Fast Food Restaurant
# 93           Travel & Transport                Tram Station
# 94           Travel & Transport                    Bus Stop
# 95                         Food                 Pizza Place
# 96                         Food                       Diner
#
#                           Lv2               Lv3
# 0                        None              None
# 1                        None              None
# 2             Thai Restaurant              None
# 3                        None              None
# 4                        None              None
# 5                        None              None
# 6                        None              None
# 7            Tapas Restaurant              None
# 8                        None              None
# 9                        None              None
# 10                       None              None
# 11                       None              None
# 12        Japanese Restaurant              None
# 13                       None              None
# 14      Vietnamese Restaurant              None
# 15                       None              None
# 16                       None              None
# 17                       None              None
# 18                       None              None
# 19                       None              None
# 20                       None              None
# 21                       None              None
# 22             Ice Cream Shop              None
# 23                       None              None
# 24                       None              None
# 25                       None              None
# 26                   Dive Bar              None
# 27        Japanese Restaurant              None
# 28                       None              None
# 29                       None              None
# 30                       None              None
# 31                       None              None
# 32                       None              None
# 33                       None              None
# 34                       None              None
# 35                       None              None
# 36                       None              None
# 37                       None              None
# 38                       None              None
# 39                       None              None
# 40                       None              None
# 41                       None              None
# 42        Japanese Restaurant              None
# 43                       None              None
# 44                       None              None
# 45                       None              None
# 46                       None              None
# 47                  Wine Shop              None
# 48                       None              None
# 49             Ice Cream Shop              None
# 50                       None              None
# 51                       None              None
# 52                       None              None
# 53                       None              None
# 54                       None              None
# 55        Moroccan Restaurant              None
# 56                       None              None
# 57        Monument / Landmark              None
# 58                   Wine Bar              None
# 59                       None              None
# 60               Noodle House              None
# 61                       None              None
# 62                       None              None
# 63                       None              None
# 64                       None              None
# 65                       None              None
# 66        Japanese Restaurant  Ramen Restaurant
# 67          Trattoria/Osteria              None
# 68                       None              None
# 69                        Pub              None
# 70                       None              None
# 71                       None              None
# 72                       None              None
# 73       Gym / Fitness Center               Gym
# 74                       None              None
# 75  South American Restaurant              None
# 76        Japanese Restaurant  Sushi Restaurant
# 77                       None              None
# 78                       None              None
# 79                       None              None
# 80                       None              None
# 81                       None              None
# 82          Korean Restaurant              None
# 83                       None              None
# 84                       None              None
# 85                       None              None
# 86                  Multiplex              None
# 87                       None              None
# 88                       None              None
# 89                       None              None
# 90                       None              None
# 91            Thai Restaurant              None
# 92                       None              None
# 93                       None              None
# 94                       None              None
# 95                       None              None
# 96                       None              None

# %%
### Find all Lv0 values
lv0_list = []
for key in dic2:
    temp_list = list(dic2[key]['Lv0'].unique())
    
    for element in temp_list:
        if element not in lv0_list:
            lv0_list.append(element)
    
lv0_list
# Out:
# ['Food',
#  'Shop & Service',
#  'Travel & Transport',
#  'Outdoors & Recreation',
#  'Arts & Entertainment',
#  'Nightlife Spot',
#  'Professional & Other Places',
#  'Residence']

# %%
### add Lv0 hot encoding keys to df
for element in lv0_list:
    df[element] = df.apply(lambda row: 0, axis = 1)

# %%
## we check the new dataframe
df.head()
# Out:
#           cityName  extraPrice  price  latitude  longitude  numberOfRooms  \
# 6065071     Genève       350.0   2550  46.19363    6.16698            4.0
# 6046525     Genève       200.0   4200  46.19646    6.16090            5.5
# 6063101     Genève       170.0   2810  46.20429    6.15891            4.0
# 6054808     Genève       250.0   4750  46.19523    6.15391            7.0
# 6037279  Le Lignon       200.0   2700  46.20313    6.09613            6.0
#
#                         street  surfaceLiving   zip  pricePerRoom  \
# 6065071    Rue Le Corbusier 18             85  1208    637.500000
# 6046525  Route de Malagnou 40E            110  1208    763.636364
# 6063101  Rue du 31-Décembre 16             60  1207    702.500000
# 6054808           Rue Marignac            165  1206    678.571429
# 6037279       Avenue du Lignon            107  1219    450.000000
#
#          pricePerSqm  price_dev  Food  Shop & Service  Travel & Transport  \
# 6065071    30.000000  -0.171515     0               0                   0
# 6046525    38.181818   0.105094     0               0                   0
# 6063101    46.833333   0.211344     0               0                   0
# 6054808    28.787879  -0.148491     0               0                   0
# 6037279    25.233645  -0.357799     0               0                   0
#
#          Outdoors & Recreation  Arts & Entertainment  Nightlife Spot  \
# 6065071                      0                     0               0
# 6046525                      0                     0               0
# 6063101                      0                     0               0
# 6054808                      0                     0               0
# 6037279                      0                     0               0
#
#          Professional & Other Places  Residence
# 6065071                            0          0
# 6046525                            0          0
# 6063101                            0          0
# 6054808                            0          0
# 6037279                            0          0

# %%
# one hot encoding.
lv0_onehot = pd.DataFrame(pd.get_dummies(dic2[list(dic2.keys())[0]]['Lv0'], prefix="", prefix_sep="").sum())

# %%
##  For each property we count the number of venues for each category ('Food', etc.)

for app_id in df.index:
    lv0_onehot = pd.DataFrame(pd.get_dummies(dic2[app_id]['Lv0'], prefix="", prefix_sep="").sum())
    for one_hot in lv0_list:
        if one_hot in lv0_onehot.index:
             df.loc[app_id, one_hot] = lv0_onehot.loc[one_hot, 0]

# %%
## we check the final dataframe
df.head()
# Out:
#           cityName  extraPrice  price  latitude  longitude  numberOfRooms  \
# 6065071     Genève       350.0   2550  46.19363    6.16698            4.0
# 6046525     Genève       200.0   4200  46.19646    6.16090            5.5
# 6063101     Genève       170.0   2810  46.20429    6.15891            4.0
# 6054808     Genève       250.0   4750  46.19523    6.15391            7.0
# 6037279  Le Lignon       200.0   2700  46.20313    6.09613            6.0
#
#                         street  surfaceLiving   zip  pricePerRoom  \
# 6065071    Rue Le Corbusier 18             85  1208    637.500000
# 6046525  Route de Malagnou 40E            110  1208    763.636364
# 6063101  Rue du 31-Décembre 16             60  1207    702.500000
# 6054808           Rue Marignac            165  1206    678.571429
# 6037279       Avenue du Lignon            107  1219    450.000000
#
#          pricePerSqm  price_dev  Food  Shop & Service  Travel & Transport  \
# 6065071    30.000000  -0.171515     7               3                   3
# 6046525    38.181818   0.105094    22               7                   3
# 6063101    46.833333   0.211344    29               3                   1
# 6054808    28.787879  -0.148491    21               3                   3
# 6037279    25.233645  -0.357799     3               1                   0
#
#          Outdoors & Recreation  Arts & Entertainment  Nightlife Spot  \
# 6065071                      0                     0               0
# 6046525                      2                     1               1
# 6063101                      2                     1               6
# 6054808                      1                     2               1
# 6037279                      1                     0               0
#
#          Professional & Other Places  Residence
# 6065071                            0          0
# 6046525                            0          0
# 6063101                            0          0
# 6054808                            0          0
# 6037279                            0          0

# %%
## Finally, we can store the results in a file for later use 
df.to_csv(r'geneva_allapp.csv')
